# %%
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
# Specify the file name
tranad_results={}
tranad_results["anomalous_percentage"]=[]
labels=[]
omni_results={}
omni_results["anomalous_percentage"]=[]

usad_results={}
usad_results["anomalous_percentage"]=[]


# Open and read the JSON file
with open('root_cause_result_tranad.json', 'r') as file:
    tranad = json.load(file)

# Print the data
# print(tranad)
for item in tranad:
    print(item[0],item[1])
    tranad_results["anomalous_percentage"].append(item[1])
    labels.append(item[0])


print("Omni")

with open('root_cause_result_OmniAnomaly.json', 'r') as file:
    omni = json.load(file)
for item in omni:
    print(item[0],item[1])
    omni_results["anomalous_percentage"].append(item[1])

print("Usad")
with open('root_cause_result_usad.json', 'r') as file:
    usad = json.load(file)
for item in usad:
    print(item[0],item[1])
    usad_results["anomalous_percentage"].append(item[1])
# Out:
# partial-authentication-outage 60.47819971870605
# chiuc-site-maintenance-feb-6th-2024 96.05263157894737
# april-4-jupyterhub-outage 100.0
# chiuc-uplink-networking 91.80327868852459
# chiuc-maintenance-window-for-openstack-version-upgrade 100.0
# chincar-maintenance 42.33287046220988
# chiedge-outage 90.42331714087439
# upcoming-maintenance-window-for-chameleon-auth-server-june-2024 100.0
# april-16th-brief-maintenance-affecting-chiuc-network-uplink 100.0
# planned-help-desk-outage 87.45098039215686
# kvmtacc-system-maintenance 91.55844155844156
# chitacc-certificate-expiry 75.47846889952153
# upcoming-maintenance-window-for-chameleon-auth-server-june-18th-2024 100.0
# chameleon-portal-chiedge-and-jupyterhub 99.80099502487563
# chiuc-network-uplink-maintenance 51.99286139202856
# Omni
# partial-authentication-outage 52.81293952180028
# chiuc-site-maintenance-feb-6th-2024 63.450292397660824
# april-4-jupyterhub-outage 100.0
# chiuc-uplink-networking 80.32786885245902
# ...

# %%
omni
# Out:
# [['partial-authentication-outage',
#   52.81293952180028,
#   [['memory_used_metric_data', 0.9933422103861518],
#    ['memory_buffer_usage_metric_data', 0.9653794940079894],
#    ['node_time_seconds_metric_data', 0.9201065246338216],
#    ['node_context_switches_total_metric_data', 0.8921438082556591],
#    ['memory_cache_usage_metric_data', 0.5179760319573902]]],
#  ['chiuc-site-maintenance-feb-6th-2024',
#   63.450292397660824,
#   [['swap_usage_metric_data', 0.9953917050691244],
#    ['memory_used_metric_data', 0.9829493087557604],
#    ['memory_buffer_usage_metric_data', 0.9387096774193548],
#    ['inode_utilization_ratio_metric_data', 0.6815668202764977],
#    ['memory_cache_usage_metric_data', 0.5815668202764976]]],
#  ['april-4-jupyterhub-outage',
#   100.0,
#   [['node_forks_total_metric_data', 0.5555555555555556],
#    ['swap_usage_metric_data', 0.5555555555555556],
#    ['node_disk_read_bytes_total_metric_data', 0.4444444444444444],
# ...

# %%
# Provided data


method1 = [10, 60, 70, 90, 50]
method2 = [20, 50, 80, 86, 84]
method3 = [50, 90, 95, 67, 55]

# Define the width of each bar
bar_width = 0.2

# Create an array for the x-axis positions
r1 = np.arange(len(omni_results["anomalous_percentage"]))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Plotting the data as bar plots
plt.figure(figsize=(12, 6))
plt.bar(r1, omni_results["anomalous_percentage"], color='blue', width=bar_width, edgecolor='grey', label='Omni Anomaly')
plt.bar(r2, tranad_results["anomalous_percentage"], color='green', width=bar_width, edgecolor='grey', label='TranAD')
plt.bar(r3, usad_results["anomalous_percentage"], color='red', width=bar_width, edgecolor='grey', label='USAD')

# Adding labels and title
plt.xlabel('Outage', fontweight='bold')
plt.ylabel('Anomalous data Percentage (%)', fontweight='bold')
plt.title('Comparison of Methods Across Outages', fontweight='bold')

# X-axis labels
plt.xticks([r + bar_width for r in range(len(omni_results["anomalous_percentage"]))], labels,rotation=90)

# Displaying the legend
plt.legend()

# Show the plot
plt.grid(True, axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


outage=0
for label in labels:
    print(label)
    print(omni[outage][2])
    print(tranad[outage][2])
    outage+=1
    print("************************")
# Data
    data1 =omni[outage][2]

    data2 = tranad[outage][2]

    data3 = usad[outage][2]

# Extracting metric names and values
    labels1, values1 = zip(*data1)
    labels2, values2 = zip(*data2)
    labels3, values3 = zip(*data3)
    
    # Combine labels for x-axis
    all_labels = list(labels1) + list(labels2) + list(labels3)
    
    # Set up the bar positions with offsets
    
    x1 = [0,0.25,0.5,.75,1]  # Evenly spaced x positions for bars
    x2=[ 1.5,1.75,2,2.25,2.5]
    x3=[ 3,3.25,3.5,3.75,4]
    
    # Create subplots
    fig, ax = plt.subplots(figsize=(10, 6))
    
    # Plot the first set of data
    bars1 = ax.bar(x1, values1, width=0.2, label='Omni Anomaly', color='blue')
    
    # Plot the second set of data
    bars2 = ax.bar(x2, values2, width=0.2, label='TranAD', color='yellow')

    bars3 = ax.bar(x3, values3, width=0.2, label='USAD', color='red')
    
    # Adding labels and title
    ax.set_xlabel('Metrics')
    ax.set_ylabel( 'Metric present in top 5 contributors to anomaly score(%)')
    ax.set_title(label)
    ax.set_xticks(np.concatenate((x1, x2,x3)))  # Set ticks to include both datasets
    ax.set_xticklabels(all_labels, rotation=90, ha='right')  # Use combined labels
    ax.legend()
    
    # Adding value annotations on bars
    def add_value_labels(bars):
        for bar in bars:
            yval = bar.get_height()
            ax.annotate(f'{yval:.2f}', 
                        xy=(bar.get_x() + bar.get_width() / 2, yval), 
                        ha='center', va='bottom')
    
    add_value_labels(bars1)
    add_value_labels(bars2)
    
    # Show the plot
    plt.tight_layout()
    plt.show()
# Out:
# partial-authentication-outage
# [['memory_used_metric_data', 0.9933422103861518], ['memory_buffer_usage_metric_data', 0.9653794940079894], ['node_time_seconds_metric_data', 0.9201065246338216], ['node_context_switches_total_metric_data', 0.8921438082556591], ['memory_cache_usage_metric_data', 0.5179760319573902]]
# [['node_time_seconds_metric_data', 0.9918604651162791], ['node_context_switches_total_metric_data', 0.9848837209302326], ['node_network_receive_packets_total_metric_data', 0.8104651162790698], ['inode_utilization_ratio_metric_data', 0.4569767441860465], ['node_network_transmit_packets_total_metric_data', 0.44534883720930235]]
# ************************
# chiuc-site-maintenance-feb-6th-2024
# [['swap_usage_metric_data', 0.9953917050691244], ['memory_used_metric_data', 0.9829493087557604], ['memory_buffer_usage_metric_data', 0.9387096774193548], ['inode_utilization_ratio_metric_data', 0.6815668202764977], ['memory_cache_usage_metric_data', 0.5815668202764976]]
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
data1 = [['memory_used_metric_data', 0.9933422103861518],
          ['memory_buffer_usage_metric_data', 0.9653794940079894],
          ['node_time_seconds_metric_data', 0.9201065246338216],
          ['node_context_switches_total_metric_data', 0.8921438082556591],
          ['memory_cache_usage_metric_data', 0.5179760319573902]]

data2 = [['node_time_seconds_metric_data', 0.9918604651162791],
          ['node_context_switches_total_metric_data', 0.9848837209302326],
          ['node_network_receive_packets_total_metric_data', 0.8104651162790698],
          ['inode_utilization_ratio_metric_data', 0.4569767441860465],
          ['node_network_transmit_packets_total_metric_data', 0.44534883720930235]]

# Extracting metric names and values
labels1, values1 = zip(*data1)
labels2, values2 = zip(*data2)

# Set up the bar positions
x = np.arange(len(labels1))

# Create subplots
fig, ax = plt.subplots(figsize=(12, 6))

# Plot the first set of data
bars1 = ax.bar(x - 0.2, values1, width=0.2, label='First Data Set', color='blue')

# Plot the second set of data
bars2 = ax.bar(x + 0.2, values2, width=0.2, label='Second Data Set', color='orange')

# Adding labels and title
ax.set_xlabel('Metrics')
ax.set_ylabel('Values')
ax.set_title('Partial Authentication Outage Metrics')
ax.set_xticks(x)
ax.set_xticklabels(labels1)
ax.legend()

# Adding value annotations on bars
def add_value_labels(bars):
    for bar in bars:
        yval = bar.get_height()
        ax.annotate(f'{yval:.2f}', 
                    xy=(bar.get_x() + bar.get_width() / 2, yval), 
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

# Show the plot
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
data1 = [['memory_used_metric_data', 0.9933422103861518],
          ['memory_buffer_usage_metric_data', 0.9653794940079894],
          ['node_time_seconds_metric_data', 0.9201065246338216],
          ['node_context_switches_total_metric_data', 0.8921438082556591],
          ['memory_cache_usage_metric_data', 0.5179760319573902]]

data2 = [['node_time_seconds_metric_data', 0.9918604651162791],
          ['node_context_switches_total_metric_data', 0.9848837209302326],
          ['node_network_receive_packets_total_metric_data', 0.8104651162790698],
          ['inode_utilization_ratio_metric_data', 0.4569767441860465],
          ['node_network_transmit_packets_total_metric_data', 0.44534883720930235]]

# Extracting metric names and values
labels1, values1 = zip(*data1)
labels2, values2 = zip(*data2)

# Combine labels for x-axis
all_labels = list(labels1) + list(labels2)

# Set up the bar positions with offsets
x1 = np.arange(len(labels1))  # Positions for dataset 1
x2 = np.arange(len(labels1), len(labels1) + len(labels2))  # Positions for dataset 2

# Create subplots
fig, ax = plt.subplots(figsize=(12, 6))

# Plot the first set of data
bars1 = ax.bar(x1, values1, width=0.4, label='Dataset 1', color='blue')

# Plot the second set of data
bars2 = ax.bar(x2, values2, width=0.4, label='Dataset 2', color='orange')

# Adding labels and title
ax.set_xlabel('Metrics')
ax.set_ylabel('Values')
ax.set_title('Partial Authentication Outage Metrics')
ax.set_xticks(np.concatenate((x1, x2)))  # Set ticks to include both datasets
ax.set_xticklabels(all_labels, rotation=90, ha='right')  # Use combined labels
ax.legend()

# Adding value annotations on bars
def add_value_labels(bars):
    for bar in bars:
        yval = bar.get_height()
        ax.annotate(f'{yval:.2f}', 
                    xy=(bar.get_x() + bar.get_width() / 2, yval), 
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
data1 = [['memory_used_metric_data', 0.9933422103861518],
          ['memory_buffer_usage_metric_data', 0.9653794940079894],
          ['node_time_seconds_metric_data', 0.9201065246338216],
          ['node_context_switches_total_metric_data', 0.8921438082556591],
          ['memory_cache_usage_metric_data', 0.5179760319573902]]

data2 = [['node_time_seconds_metric_data', 0.9918604651162791],
          ['node_context_switches_total_metric_data', 0.9848837209302326],
          ['node_network_receive_packets_total_metric_data', 0.8104651162790698],
          ['inode_utilization_ratio_metric_data', 0.4569767441860465],
          ['node_network_transmit_packets_total_metric_data', 0.44534883720930235]]

# Extracting metric names and values
labels1, values1 = zip(*data1)
labels2, values2 = zip(*data2)

# Combine labels for x-axis
all_labels = list(labels1) + list(labels2)

# Set up the bar positions
bar_width = 0.35  # Width of each bar
x1 = np.arange(len(labels1))  # Positions for dataset 1
x2 = x1 + bar_width  # Positions for dataset 2, closer to dataset 1

# Create subplots
fig, ax = plt.subplots(figsize=(12, 6))

# Plot the first set of data
bars1 = ax.bar(x1, values1, width=bar_width, label='Dataset 1', color='blue')

# Plot the second set of data
bars2 = ax.bar(x2, values2, width=bar_width, label='Dataset 2', color='orange')

# Adding labels and title
ax.set_xlabel('Metrics')
ax.set_ylabel('Values')
ax.set_title('Partial Authentication Outage Metrics')
ax.set_xticks(x1 + bar_width / 2)  # Set ticks to the center of the grouped bars
ax.set_xticklabels(all_labels, rotation=45, ha='right')  # Use combined labels
ax.legend()

# Adding value annotations on bars
def add_value_labels(bars):
    for bar in bars:
        yval = bar.get_height()
        ax.annotate(f'{yval:.2f}', 
                    xy=(bar.get_x() + bar.get_width() / 2, yval), 
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 43
#      41 ax.set_title('Partial Authentication Outage Metrics')
#      42 ax.set_xticks(x1 + bar_width / 2)  # Set ticks to the center of the grouped bars
# ---> 43 ax.set_xticklabels(all_labels, rotation=45, ha='right')  # Use combined labels
#      44 ax.legend()
#      46 # Adding value annotations on bars
#
# File ~/miniconda3/envs/py_39/lib/python3.9/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~/miniconda3/envs/py_39/lib/python3.9/site-packages/matplotlib/axis.py:2071, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2067 elif isinstance(locator, mticker.FixedLocator):
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from Method 1 and Method 2
method1 = [['memory_used_metric_data', 0.9933422103861518],
            ['memory_buffer_usage_metric_data', 0.9653794940079894],
            ['node_time_seconds_metric_data', 0.9201065246338216],
            ['node_context_switches_total_metric_data', 0.8921438082556591],
            ['memory_cache_usage_metric_data', 0.5179760319573902]]

method2 = [['node_time_seconds_metric_data', 0.9918604651162791],
            ['node_context_switches_total_metric_data', 0.9848837209302326],
            ['node_network_receive_packets_total_metric_data', 0.8104651162790698],
            ['inode_utilization_ratio_metric_data', 0.4569767441860465],
            ['node_network_transmit_packets_total_metric_data', 0.44534883720930235]]

# Convert to numpy arrays for plotting
method1_labels, method1_values = zip(*method1)
method2_labels, method2_values = zip(*method2)

# Set up the bar positions
bar_width = 0.35
index1 = np.arange(len(method1_values))  # Index for Method 1
index2 = np.arange(len(method2_values))  # Index for Method 2

# Create the plot
plt.figure(figsize=(10, 6))
bars1 = plt.bar(index1, method1_values, bar_width, label='Method 1', color='blue')
bars2 = plt.bar(index2 + bar_width, method2_values, bar_width, label='Method 2', color='orange')

# Combine labels for x-axis, keeping them distinct for the x-axis
combined_labels = list(method1_labels) + list(method2_labels)

# Adjust x-ticks to show both sets of labels
xticks_positions = np.arange(len(method1_values) + len(method2_values))  # Total number of bars
plt.xticks(xticks_positions + bar_width / 2, combined_labels, rotation=45, ha='right')

# Add labels and title
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.title('Comparison of Leading Causes from Method 1 and Method 2')
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
method1_labels
# Out:
# ('memory_used_metric_data',
#  'memory_buffer_usage_metric_data',
#  'node_time_seconds_metric_data',
#  'node_context_switches_total_metric_data',
#  'memory_cache_usage_metric_data')

# %%
combined_labels
# Out:
# ['node_network_receive_packets_total_metric_data',
#  'inode_utilization_ratio_metric_data',
#  'node_time_seconds_metric_data',
#  'memory_used_metric_data',
#  'node_network_transmit_packets_total_metric_data',
#  'memory_buffer_usage_metric_data',
#  'node_context_switches_total_metric_data',
#  'memory_cache_usage_metric_data']

# %%
import matplotlib.pyplot as plt
import numpy as np

method1_data = [['memory_used_metric_data', 0.9933422103861518],
                ['memory_buffer_usage_metric_data', 0.9653794940079894],
                ['node_time_seconds_metric_data', 0.9201065246338216],
                ['node_context_switches_total_metric_data', 0.8921438082556591],
                ['memory_cache_usage_metric_data', 0.5179760319573902]]

method2_data = [['node_time_seconds_metric_data', 0.9918604651162791],
                ['node_context_switches_total_metric_data', 0.9848837209302326],
                ['node_network_receive_packets_total_metric_data', 0.8104651162790698],
                ['inode_utilization_ratio_metric_data', 0.4569767441860465],
                ['node_network_transmit_packets_total_metric_data', 0.44534883720930235]]

# Extract labels and values for each method
method1_labels = [item[0] for item in method1_data]
method1_values = [item[1] for item in method1_data]
method2_labels = [item[0] for item in method2_data]
method2_values = [item[1] for item in method2_data]

# Create grouped bars
width = 0.35
ind = np.arange(len(method1_labels))

plt.figure(figsize=(10, 6))
plt.bar(ind, method1_values, width, label='Method 1')
plt.bar(ind + width, method2_values, width, label='Method 2')

# Set labels and title
plt.xlabel('Leading Causes')
plt.ylabel('Value')
plt.title('Comparison of Leading Causes')

# Set x-axis labels
plt.xticks(ind + width / 2, method1_labels, rotation=90)

# Add legend
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for the first bar plot
categories1 = ['A', 'B', 'C']
values1 = [3, 7, 5]

# Sample data for the second bar plot
categories2 = ['A', 'B', 'C']
values2 = [4, 6, 8]

# Set width of bar
bar_width = 0.35
index = np.arange(len(categories1))

# Create a single figure
plt.figure(figsize=(10, 5))

# Create the first bar plot
plt.bar(index, values1, bar_width, label='Dataset 1', color='blue')

# Create the second bar plot next to the first
plt.bar(index + bar_width, values2, bar_width, label='Dataset 2', color='red')

# Adding labels and title
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Merged Bar Plots')
plt.xticks(index + bar_width / 2, categories1)
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for the first dataset
categories = ['A', 'B', 'C']
values1 = [3, 7, 5]

# Sample data for the second dataset
values2 = [4, 6, 8]

# Set width of bars
bar_width = 0.35
index = np.arange(len(categories))

# Create a single figure
plt.figure(figsize=(10, 5))

# Create the first bar plot
plt.bar(index, values1, bar_width, label='Dataset 1', color='blue')

# Create the second bar plot next to the first
plt.bar(index + bar_width, values2, bar_width, label='Dataset 2', color='red')

# Adding labels and title
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Grouped Bar Plot')
plt.xticks(index + bar_width / 2, categories)  # Center the tick labels
plt.legend()

# Show the plot
plt.tight_layout()  # Adjust layout to prevent clipping of tick-labels
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for two different categories
labels = ['Category A', 'Category B', 'Category C']
data1 = [5, 7, 8]  # Data for the first bar plot
data2 = [6, 9, 4]  # Data for the second bar plot

# Define the positions of the bars
x = np.arange(len(labels))

# Width of a single bar
bar_width = 0.35

# Create the bar plots
plt.bar(x - bar_width / 2, data1, width=bar_width, label='Data Set 1', color='blue')
plt.bar(x + bar_width / 2, data2, width=bar_width, label='Data Set 2', color='orange')

# Add labels and title
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Combined Bar Plot')
plt.xticks(x, labels)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for two different datasets
labels = ['Category A', 'Category B', 'Category C']
data1 = [5, 7, 8]  # Data for the first dataset
data2 = [6, 9, 4]  # Data for the second dataset

# Define the positions of the bars
x = np.arange(len(labels))  # The label locations

# Width of a single bar
bar_width = 0.35

# Create the bar plots
plt.bar(x, data1, width=bar_width, label='Data Set 1', color='blue', align='center')
plt.bar(x, data2, width=bar_width, label='Data Set 2', color='orange', bottom=data1)

# Add labels and title
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Grouped Bar Plot')
plt.xticks(x, labels)  # Center the x-ticks on the groups
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data
categories = ['Category 1', 'Category 2', 'Category 3', 'Category 4']
values = [10, 20, 15, 25] 
values2=[10,15,50]

# Define custom x-ticks and their positions
custom_ticks = ['A', 'B', 'C','D']
custom_ticks2=['e','f','g']
x_pos = [0,0.5,1,1.5]  # Evenly spaced x positions for bars
x2_pos=[ 2.5,3,3.5]
# Custom bar width and spacing
bar_width = 0.4  # Adjust bar width

# Create bar chart
plt.bar(x_pos, values, width=bar_width,label='Data Set 1', color='blue', align='center')
plt.bar(x2_pos, values2, width=bar_width,label='Data Set 2', color='orange', align='center')

# Set custom x-ticks
plt.xticks(ticks=x_pos, labels=custom_ticks,rotation=90)
plt.xticks(ticks=x2_pos, labels=custom_ticks2,rotation=90)
# Adjust x-axis tick spacing by using a custom range or spacing
plt.xlim([-0.5, len(categories) - 0.5])  # Optional: Control the limits of the x-axis for spacing

# Add labels and title
plt.xlabel('Custom X-Ticks')
plt.ylabel('Values')
plt.title('Bar Chart with Custom X-Ticks and Bar Spacing')

# Show the plot
plt.show()

# %%
np.arange(len(categories))
# Out:
# array([0, 1, 2, 3])

# %%
# Out:
# Category A
# [['memory_used_metric_data', 0.9933422103861518], ['memory_buffer_usage_metric_data', 0.9653794940079894], ['node_time_seconds_metric_data', 0.9201065246338216], ['node_context_switches_total_metric_data', 0.8921438082556591], ['memory_cache_usage_metric_data', 0.5179760319573902]]
# [['node_time_seconds_metric_data', 0.9918604651162791], ['node_context_switches_total_metric_data', 0.9848837209302326], ['node_network_receive_packets_total_metric_data', 0.8104651162790698], ['inode_utilization_ratio_metric_data', 0.4569767441860465], ['node_network_transmit_packets_total_metric_data', 0.44534883720930235]]
# ************************
# Category B
# [['swap_usage_metric_data', 0.9953917050691244], ['memory_used_metric_data', 0.9829493087557604], ['memory_buffer_usage_metric_data', 0.9387096774193548], ['inode_utilization_ratio_metric_data', 0.6815668202764977], ['memory_cache_usage_metric_data', 0.5815668202764976]]
# ...
